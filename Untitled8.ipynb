# %% [markdown]
# # 1.What is Object-Oriented Programming (OOP)?
# - Object-Oriented Programming (OOP) is a programming paradigm that combines related methods and variables in a class.
# - To use that class repeadly we want just create a object.
# - This allows code reuse, better organization, and models real-world entities more effectively.
#
# # 2.What is a class in OOP?
# - In OOPs class is used to store related methods and variables.
# - Class is blue print used for creating Objects.
#
# # 3.What is an object in OOP?
# - object is a instance of class.
# - It represents a real-world entity and has access to the data (attributes) and behavior (methods) defined in the class.
#
# # 4.What is the difference between abstraction and encapsulation?
# - Abstraction means hiding internal implementation of the program from the user.
# - Encapsulation means bundling related variables and methods into a single unit (class), and restricting direct access to some of the object's components.
#
# # 5.What are dunder methods in Python?
# - dunder methods are also known as special methods that start and end with double underscores.
# - These methods are automatically called by Python during certain operations.
#
# # 6.Explain the concept of inheritance in OOP?
# - Inheritence provides a better way of accessing one or more classes methods and variables from one class
# - It promotes code reusability and helps in building a hierarchical classification.
#
# # 7.What is polymorphism in OOP?
# - polymorphism means having many forms.
# - polymorphism can be achieved through method overloading and methodOverriding.
# - methodOverloading cannot directly implement in python.
#
# # 8.How is encapsulation achieved in Python?
# - By creating classes, we can achieve encapsulation in python.
# - To restrict access to internal data, Python uses access modifiers:
#
#   - Variables with a single underscore (e.g., _name) are protected (intended to be accessed within the class and its subclasses).
#
#   - Variables with double underscores (e.g., __name) are private (not directly accessible from outside the class)
#
# # 9.What is a constructor in Python?
# - Constructor is used initialize the object.
# - It is called automatically when the object is created.
# - In Python, the constructor method is named __init__().
#
# # 10.What are class and static methods in Python?
#
# - A class method is a method that is bound to the class, not the instance. It takes cls as the first parameter and is defined using the @classmethod decorator.
#
#   - It can access or modify class-level data and can be called using either the class name or an instance.
#
# - A static method does not take self or cls as the first argument and is defined using the @staticmethod decorator.
#
#   - It behaves like a regular function but lives inside the class’s namespace. It does not access or modify class or instance data.
#
#   - It can be called using the class name or an object
#
# # 11.What is method overloading in Python?
#
# - method overloading cannot directly acheived in python.
# - Python uses one method and default arguments to achieve it.
#
# # 12.What is method overriding in OOP?
# - when we inherit a class and we are unhappy or want to change a method implementation then we use method Overriding.
# - method Overriding is mostly used in Inheritence Concept.
#
# # 13.What is a property decorator in Python?
# - The @property decorator in Python is used to define a method as a property, so it can be accessed like an attribute, without using parentheses.
#
# # 14.Why is polymorphism important in OOP?
# - polymorphism is useful in situations where we want the methods to behave differently according to situations.
#
# # 15.What is an abstract class in Python?
# - abstract class is used to hide the information from the user as it only contains definition.
# - The implementation for the methods that are defined in the abstract class can be provides in the subclass that inherit the abstract class.
#
# # 16.What are the advantages of OOP?
# - Modularity
# - Reusability
# - Abstraction
# - Polymophism
# - Encapsulation
# - Inheritence
#
# # 17. What is the difference between a class variable and an instance variable?
# - The variable that can be initialized within the class and within the methods is called instance variable.
# - The variable that can be initialized within the class and outside the methods is calles class variable.
#
# # 18.What is multiple inheritance in Python?
# - A class inheriting more than one class is called multiple inheritence.
#
# # 19.Explain the purpose of ‘’__str__’ and ‘__repr__’ ‘ methods in Python?
# - __str__ is used to return a user-friendly string when we print an object.
#
# - __repr__ is used to return a developer-friendly string, usually meant for debugging.
#
# - __str__ is called by print() and str(), while __repr__ is called by repr() or in the Python shell.
#
# # 20.What is the significance of the ‘super()’ function in Python?
# - it is used to called the constructor of the parent class.
#
# # 21.What is the significance of the __del__ method in Python?
# - The __del__ method is called a destructor.
# - It is automatically called when an object is about to be destroyed or garbage collected.
# - It is used to clean up resources, like closing files or releasing memory.
#
# # 22.What is the difference between @staticmethod and @classmethod in Python?
# - @staticmethod: Defines a method that does not depend on class or instance.
# - @classmethod: Defines a method that works with the class itself (cls), not the instance.
#
# # 23.How does polymorphism work in Python with inheritance?
# - Polymorphism in Python with inheritance allows a subclass to provide its own implementation of a parent class method, and the method that runs is chosen at runtime based on the object’s type.
#
# #24.What is method chaining in Python OOP?
# - Method chaining in Python OOP is calling multiple methods in a single line because each method returns the same object (self).
#
# #25.What is the purpose of the __call__ method in Python?
# - In Python, the __call__ method is a special method that allows an instance of a class to be called like a function.

# %%
#Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog
#that overrides the speak() method to print "Bark!".
class Animal:
  def speak(self):
    print("Hello, I am Animal.")
class Dog(Animal):
  def speak(self):
    print("Bark!")
obj1 = Dog();
obj1.speak()
# Out:
# Bark!

# %%
#2. Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle
#from it and implement the area() method in both.
from abc import ABC, abstractmethod
import math

class Shape(ABC):

    @abstractmethod
    def area(self):
        pass

class Circle(Shape):

    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return math.pi * self.radius ** 2

class Rectangle(Shape):

    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

circle = Circle(5)
rectangle = Rectangle(4, 6)

print(f"Area of Circle: {circle.area():.2f}")
print(f"Area of Rectangle: {rectangle.area():.2f}")
# Out:
# Area of Circle: 78.54
# Area of Rectangle: 24.00

# %%
# Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car
#and further derive a class ElectricCar that adds a battery attribute.
class Vehicle:
    def __init__(self, v_type):
        self.v_type = v_type

    def showDetails(self):
        print(f"Type: {self.v_type}")
class Car(Vehicle):
    def __init__(self, v_type, speed, mileage):
        super().__init__(v_type)
        self.speed = speed
        self.mileage = mileage

    def showDetails(self):
        super().showDetails()
        print(f"Speed: {self.speed} km/h, Mileage: {self.mileage} km/l")
class ElectricCar(Car):
    def __init__(self, v_type, speed, mileage, batteryPow):
        super().__init__(v_type, speed, mileage)
        self.batteryPow = batteryPow

    def showDetails(self):
        super().showDetails()
        print(f"Battery Power: {self.batteryPow} kWh")
ecar = ElectricCar("Electric", 150, 18, 85)
ecar.showDetails()
# Out:
# Type: Electric
# Speed: 150 km/h, Mileage: 18 km/l
# Battery Power: 85 kWh

# %%
# Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes
#Sparrow and Penguin that override the fly() method.
class Bird:
  def fly(self):
    print("I am a bird at base class")
class Sparrow(Bird):
  def fly(self):
    print("I am bird at Sparrow class so I am a Sparrow.")
class Penguin(Bird):
  def fly(self):
    print("I am bird at Penguin class so I am a Penguin.")
bird = Bird()
bird1 = Sparrow()
bird2 = Penguin()
bird.fly()
bird1.fly()
bird2.fly()
# Out:
# I am a bird at base class
# I am bird at Sparrow class so I am a Sparrow.
# I am bird at Penguin class so I am a Penguin.

# %%
# Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes
#balance and methods to deposit, withdraw, and check balance.
class BankAccount:
  def __init__(self, balance):
    self.__balance = balance
  def deposit(self, amount):
    self.__balance += amount
  def withdraw(self, amount):
    if(self.__balance >= amount):
      self.__balance -= amount
    else:
      print("Please deposite Money Before Withdraw!")
  def checkBalance(self):
    return self.__balance
bank1 = BankAccount(1000)
bank1.deposit(100)
bank1.withdraw(200)
bank1.checkBalance()
# Out:
# 900

# %%
#Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar
#and Piano that implement their own version of play().

class Instrument:
    def play(self):
        print("Playing some instrument...")

class Guitar(Instrument):
    def play(self):
        print("Strumming the guitar ")

class Piano(Instrument):
    def play(self):
        print("Playing the piano ")
i = Instrument()
i.play()
i1 = Guitar()
i1.play()
i2 = Piano()
i2.play()
# Out:
# Playing some instrument...
# Strumming the guitar
# Playing the piano

# %%
#Create a class MathOperations with a class method add_numbers() to add two numbers and a static
#method subtract_numbers() to subtract two numbers
class MathOperations:
  @classmethod
  def add_numbers(cls, a, b):
    return a + b
  @staticmethod
  def subtract_numbers(a, b):
    return a - b
print(MathOperations.add_numbers(1, 2))
print(MathOperations.subtract_numbers(5, 7))
# Out:
# 3
# -2

# %%
# Implement a class Person with a class method to count the total number of persons created.
class Person:
  count = 0
  def __init__(self):
    Person.count = Person.count + 1
  @classmethod
  def countVar(cls):
    return cls.count
Person()
Person()
Person()
Person()
Person.countVar()
# Out:
# 4

# %%
# Write a class Fraction with attributes numerator and denominator. Override the str method to display the
#fraction as "numerator/denominator".
class Fraction:
    def __init__(self, numerator, denominator):
        self.numerator = numerator
        self.denominator = denominator

    def __str__(self):
        return f"{self.numerator}/{self.denominator}"
f1 = Fraction(3, 4)
f2 = Fraction(7, 2)

print(f1)
print(f2)
# Out:
# 3/4
# 7/2

# %%
#. Demonstrate operator overloading by creating a class Vector and overriding the add method to add two
#vectors.
class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y
    def __add__(self, other):
        return Vector(self.x + other.x, self.y + other.y)

    def __str__(self):
        return f"({self.x}, {self.y})"
v1 = Vector(2, 3)
v2 = Vector(4, 5)

v3 = v1 + v2
print("Resultant Vector:", v3)
# Out:
# Resultant Vector: (6, 8)

# %%
#Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is
#{name} and I am {age} years old."
class Person:
  def __init__(self, name, age):
    self.name = name
    self.age = age
  def greet(self):
    print(f"Hello, my name is {self.name} and I am {self.age} years old.")
p1 = Person("Hemanth", 18)
p1.greet()
# Out:
# Hello, my name is Hemanth and I am 18 years old.

# %%
# Implement a class Student with attributes name and grades. Create a method average_grade() to compute
#the average of the grades
class Student:
  def __init__(self, name, grades):
    self.name = name
    self.grades = grades
  def average_grade(self):
    sum = 0
    for i in self.grades:
      sum = sum + i
    print(sum / len(self.grades))
s1 = Student("Hemanth", [1, 2])
s1.average_grade()
# Out:
# 1.5

# %%
# Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the
#area.
class Rectangle:
    def __init__(self):
        self.length = 0
        self.width = 0

    def set_dimensions(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width
rect = Rectangle()
rect.set_dimensions(5, 3)
print("Area of Rectangle:", rect.area())
# Out:
# Area of Rectangle: 15

# %%
# Create a class Employee with a method calculate_salary() that computes the salary based on hours worked
#and hourly rate. Create a derived class Manager that adds a bonus to the salary

class Employee:
    def __init__(self, hours_worked, hourly_rate):
        self.hours_worked = hours_worked
        self.hourly_rate = hourly_rate

    def calculate_salary(self):
        return self.hours_worked * self.hourly_rate


class Manager(Employee):
    def __init__(self, hours_worked, hourly_rate, bonus):
        super().__init__(hours_worked, hourly_rate)  # Call Employee constructor
        self.bonus = bonus

    def calculate_salary(self):
        base_salary = super().calculate_salary()  # Get salary from Employee
        return base_salary + self.bonus
emp = Employee(40, 20)
mgr = Manager(45, 30, 5000)
print("Employee Salary:", emp.calculate_salary())
print("Manager Salary:", mgr.calculate_salary())
# Out:
# Employee Salary: 800
# Manager Salary: 6350

# %%
#Create a class Product with attributes name, price, and quantity. Implement a method total_price() that
#calculates the total price of the product.

class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity

    def total_price(self):
        return self.price * self.quantity
p1 = Product("Laptop", 50000, 2)
p2 = Product("Headphones", 1500, 3)
print(f"Total price for {p1.name}: {p1.total_price()}")
print(f"Total price for {p2.name}: {p2.total_price()}")
# Out:
# Total price for Laptop: 100000
# Total price for Headphones: 4500

# %%
# Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that
#implement the sound() method.
from abc import ABC, abstractmethod

class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass
class Cow(Animal):
    def sound(self):
        print("Cow says: Moo!")
class Sheep(Animal):
    def sound(self):
        print("Sheep says: Baa!")
a1 = Cow()
a2 = Sheep()
a1.sound()
a2.sound()
# Out:
# Cow says: Moo!
# Sheep says: Baa!

# %%
#Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that
#returns a formatted string with the book's details.
class Book:
    def __init__(self, title, author, year_published):
        self.title = title
        self.author = author
        self.year_published = year_published

    def get_book_info(self):
        return f"'{self.title}' by {self.author}, published in {self.year_published}"
book1 = Book("To Kill a Mockingbird", "Harper Lee", 1960)
book2 = Book("1984", "George Orwell", 1949)

print(book1.get_book_info())
print(book2.get_book_info())
# Out:
# 'To Kill a Mockingbird' by Harper Lee, published in 1960
# '1984' by George Orwell, published in 1949

# %%
# Create a class House with attributes address and price. Create a derived class Mansion that adds an
#attribute number_of_rooms.
class House:
    def __init__(self, address, price):
        self.address = address
        self.price = price

    def show_details(self):
        print(f"Address: {self.address}")
        print(f"Price: {self.price}")
class Mansion(House):
    def __init__(self, address, price, number_of_rooms):
        super().__init__(address, price)
        self.number_of_rooms = number_of_rooms

    def show_details(self):
        super().show_details()
        print(f"Number of Rooms: {self.number_of_rooms}")
house = House("123 Main Street", 5000000)
mansion = Mansion("456 Luxury Avenue", 25000000, 10)
print("House Details:")
house.show_details()
print("\nMansion Details:")
mansion.show_details()
# Out:
# House Details:
# Address: 123 Main Street
# Price: 5000000
#
# Mansion Details:
# Address: 456 Luxury Avenue
# Price: 25000000
# Number of Rooms: 10
